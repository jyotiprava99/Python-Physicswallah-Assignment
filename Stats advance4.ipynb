# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.
#
# Q2: Differentiate between one-tailed and two-tailed tests.
#
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.
#
# Q4: Explain Bayes's theorem with an example.
#
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.
#
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.
#
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.
#
# Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
# Provide an example of a scenario where a larger sample size would result in a smaller margin of error.
#
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.
#
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.
#
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
# confidence interval for the true proportion of people who are satisfied with their job.
#
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
# Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.
#
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
# of 65. Calculate the 90% confidence interval for the true population mean.
#
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
# reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.

# %% [markdown]
# Q1: The main difference between a t-test and a z-test lies in the assumptions about the population standard deviation:
#
# - Z-test is used when the population standard deviation is known or when the sample size is large (typically n > 30), making the sample standard deviation a good estimate of the population standard deviation.
# Example: Testing whether the mean weight of a product is different from a specified value when the population standard deviation of weights is known.
#
# - T-test is used when the population standard deviation is unknown and must be estimated from the sample or when the sample size is small (typically n < 30).
# Example: Testing whether there is a significant difference in the mean scores of two groups of students who received different teaching methods.
#
# Q2: One-tailed tests and two-tailed tests differ in the directionality of the hypothesis being tested:
#
# - One-tailed test: It tests for a difference in one direction only (either greater than or less than). It's appropriate when there is a specific directional hypothesis.
# Example: Testing whether a new drug increases blood pressure (one-tailed greater than test).
#
# - Two-tailed test: It tests for a difference in either direction. It's appropriate when there is no specific directional hypothesis.
# Example: Testing whether a coin is fair (two-tailed test for equality of means).
#
# Q3: Type 1 and Type 2 errors are potential errors in hypothesis testing:
#
# - Type 1 error (False Positive): It occurs when the null hypothesis is rejected when it is actually true.
# Example: Concluding that a person is guilty when they are innocent in a court trial.
#
# - Type 2 error (False Negative): It occurs when the null hypothesis is not rejected when it is actually false.
# Example: Concluding that a person is innocent when they are guilty in a court trial.
#
# Q4: Bayes's theorem describes the probability of an event based on prior knowledge of conditions that might be related to the event:
#
# \[ P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)} \]
#
# Where:
# - \( P(A|B) \) is the probability of event A given that event B has occurred.
# - \( P(B|A) \) is the probability of event B given that event A has occurred.
# - \( P(A) \) and \( P(B) \) are the probabilities of events A and B, respectively.
#
# Example: Consider a medical test for a disease. \( P(A) \) is the probability of having the disease, \( P(B) \) is the probability of testing positive, \( P(A|B) \) is the probability of having the disease given a positive test result, and \( P(B|A) \) is the probability of testing positive given that the person has the disease.
#
# Q5: A confidence interval is a range of values that likely contains the population parameter of interest, typically a population mean, with a specified level of confidence:
#
# \[ \text{Confidence Interval} = \text{Sample Mean} \pm \text{Margin of Error} \]
#
# Example: Suppose we want to estimate the average height of students in a school. We take a sample of 100 students and calculate the sample mean height as 65 inches with a standard deviation of 3 inches. Assuming a 95% confidence level, we can calculate the confidence interval using the formula.
#
# \[ \text{Confidence Interval} = 65 \pm (1.96) \left( \frac{3}{\sqrt{100}} \right) \]
#
# Q6: Using Bayes' Theorem to calculate the probability of an event given prior knowledge and new evidence:
#
# Example: Suppose a medical test for a disease is known to be 99% accurate. However, the disease is rare, occurring in only 1% of the population. If a person tests positive for the disease, we can use Bayes' Theorem to calculate the probability that they actually have the disease given the prior probability of the disease and the accuracy of the test.
#
# Q7: To calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5:
#
# \[ \text{Confidence Interval} = 50 \pm (1.96) \left( \frac{5}{\sqrt{n}} \right) \]
#
# Interpretation: We are 95% confident that the true population mean lies within the interval calculated.
#
# Q8: The margin of error in a confidence interval is the range of values above and below the sample estimate within which the true population parameter is likely to lie. Sample size affects the margin of error inversely; a larger sample size results in a smaller margin of error.
#
# Example: In a political poll, a larger sample size leads to a smaller margin of error, increasing the precision of the estimate of the proportion of voters supporting a candidate.
#
# Q9: To calculate the z-score for a data point with a value of 75, a population mean of 70, and a population standard deviation of 5:
#
# \[ z = \frac{x - \mu}{\sigma} = \frac{75 - 70}{5} = 1 \]
#
# Interpretation: The data point is 1 standard deviation above the mean.
#
# Q10: Conducting a hypothesis test to determine if the new weight loss drug is significantly effective at a 95% confidence level using a t-test:
#
# - Null hypothesis (H0): The mean weight loss due to the drug is zero.
# - Alternative hypothesis (H1): The mean weight loss due to the drug is not zero.
#
# We can calculate the t-statistic using the sample mean, sample standard deviation, sample size, and the null hypothesis mean, then determine if the t-statistic falls within the critical region based on the desired confidence level.
#
# Q11: To calculate the 95% confidence interval for the true proportion of people who are satisfied with their job:
#
# \[ \text{Confidence Interval} = p \pm (1.96) \sqrt{\frac{p(1-p)}{n}} \]
#
# Where \( p = 0.65 \) (proportion of people satisfied with their job) and \( n = 500 \) (sample size).
#
# Q12: Conducting a hypothesis test to determine if the two teaching methods have a significant difference in student performance using a t-test with a significance level of 0.01:
#
# - Null hypothesis (H0): There is no significant difference in student performance between the two teaching methods.
# - Alternative hypothesis (H1): There is a significant difference in student performance between the two teaching methods.
#
# Calculate the t-statistic using the provided sample means, standard deviations, and sample sizes, then determine if the t-statistic falls within the critical region based on the desired significance level.
#
# Q13: To calculate the 90% confidence interval for the true population mean:
#
# \[ \text{Confidence Interval} = \bar{x} \pm (1.645) \left( \frac{s}{\sqrt{n}} \right) \]
#
# Where \( \bar{x} = 65 \) (sample mean), \( s = 8 \) (sample standard deviation), \( n = 50 \) (sample size).
#
# Q14: Conducting a hypothesis test to determine if caffeine has a significant effect on reaction time at a 90% confidence level using a t-test:
#
# - Null hypothesis (H0): Caffeine has no significant effect on reaction time
#
# .
# - Alternative hypothesis (H1): Caffeine has a significant effect on reaction time.
#
# Calculate the t-statistic using the provided sample mean, sample standard deviation, sample size, and the null hypothesis mean (typically 0), then determine if the t-statistic falls within the critical region based on the desired confidence level.
